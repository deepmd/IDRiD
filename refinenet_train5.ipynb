# %%
from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.autograd import Variable
import torch.nn.functional as F
import torchvision

import numpy as np
import time
from os.path import join
import copy

from loader.idrid_loader import create_idrid_loader

from torchvision import transforms
import keras_transforms
from utilities import color_transform

from utilities import metrics

from models.refinenet_4cascade import RefineNet4Cascade
#from models.unet import UNet

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /home/reza/anaconda3/envs/deep1/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# # Load Data

# %%
image_size = 512
mask_size = 128

data_dir = './inputs'
output_dir = './weights'

# %%
def train_transforms(image, mask):
    
    # Convert PIL image to 3D numpy
    image = keras_transforms.img_to_array(image, data_format='channels_last')
    mask = keras_transforms.img_to_array(mask, data_format='channels_last')    
    
    result = keras_transforms.random_horizontal_flip([image, mask])
    result = keras_transforms.random_rotation(result, 360, fill_mode='constant')
    result = keras_transforms.random_zoom(result, (1/1.15, 1.15))
    result = keras_transforms.random_shift(result, 0.08, 0.08, fill_mode='constant')
    image, mask = result[0], result[1]    
    image = color_transform.augment_color(image)
    
    # Convert 3D numpy to PIL image
    image = keras_transforms.array_to_img(image, data_format='channels_last', scale=False)
    mask = keras_transforms.array_to_img(mask, data_format='channels_last', scale=False)
    image = transforms.Resize((image_size, image_size))(image)
    mask = transforms.Resize((mask_size, mask_size))(mask)
        
    # Convert PIL image to Pytorch tensor
    image = transforms.ToTensor()(image)
    mask = transforms.ToTensor()(mask)
    
    image = transforms.Normalize([0.03305855, 0.03305855, 0.01814391], 
                         [0.1787895, 0.12863145, 0.0794853])(image)
    
    return image, mask

def valid_transforms(image, mask):
    # Convert PIL image to 3D numpy
    image = keras_transforms.img_to_array(image, data_format='channels_last')
    mask = keras_transforms.img_to_array(mask, data_format='channels_last')
    image = color_transform.augment_color(image)
    
    # Convert 3D numpy to PIL image
    image = keras_transforms.array_to_img(image, data_format='channels_last', scale=False)
    mask = keras_transforms.array_to_img(mask, data_format='channels_last', scale=False)
    image = transforms.Resize((image_size, image_size))(image)
    mask = transforms.Resize((mask_size, mask_size))(mask)
    
    # Convert PIL image to Pytorch tensor
    image = transforms.ToTensor()(image)
    mask = transforms.ToTensor()(mask)
    
    image = transforms.Normalize([0.03305855, 0.03305855, 0.01814391], 
                         [0.1787895, 0.12863145, 0.0794853])(image)

    return image, mask

data_transforms = {
    'train': train_transforms,
    'val': valid_transforms
}

image_datasets = {x: create_idrid_loader('{}/{}/'.format(data_dir, x), 
                                         '{}/{}_masks/'.format(data_dir, x), 
                                         transform=data_transforms[x], cache=False)
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], 
                                              batch_size=3,
                                              shuffle=True, 
                                              num_workers=8,
                                              pin_memory=True)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}

use_gpu = torch.cuda.is_available()
# Out:
# 40 0
# 40 0
# 10 0
# 10 0

# %% [markdown]
# # Training the model

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25, threshold=0.5):
    since = time.time()
    
    if use_gpu:
        model = model.cuda()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_sn = 0.0
    best_ppv = 0.0
    best_loss = 999999999

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-' * 10)
        
        epoch_loss_training = 0.0
        epoch_sensitivity = 0.0
        epoch_positive_predictive_value = 0.0

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                scheduler.step()
                model.train(True)  # Set model to training mode
            else:
                model.train(False)  # Set model to evaluate mode

            batch_loss_training = 0.0
            batch_sn = 0.0
            batch_ppv = 0.0

            # Iterate over data.
            for data in dataloaders[phase]:
                # get the inputs
                inputs, labels = data['raw'], data['label']

                # wrap them in Variable
                if use_gpu:
                    inputs = Variable(inputs.cuda())
                    labels = Variable(labels.cuda())#.type(torch.cuda.LongTensor)
                else:
                    inputs, labels = Variable(inputs), Variable(labels)#.type(torch.LongTensor)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                logits = model(inputs)
                
                loss_for_training = criterion(logits, labels)
                metric_sn  = metrics.SN(logits, labels, threshold) 
                metric_ppv = metrics.PPV(logits, labels, threshold)

                # backward + optimize only if in training phase
                if phase == 'train':
                    loss_for_training.backward()
                    optimizer.step()
                    
                # statistics
                batch_loss_training += loss_for_training.data[0] * inputs.size(0)
                batch_sn += metric_sn.data[0] * inputs.size(0)
                batch_ppv += metric_ppv.data[0] * inputs.size(0)

            epoch_loss_training = batch_loss_training / dataset_sizes[phase]
            epoch_sn = batch_sn / dataset_sizes[phase]
            epoch_ppv = batch_ppv / dataset_sizes[phase]
                                   
            print('{} Loss: {:.4f}, SN: {:.4f}, PPV: {:.4f}'.format(phase, epoch_loss_training,
                                                                    epoch_sn, epoch_ppv))
            # deep copy the model
            if (phase == 'val') and (epoch_sn > best_sn): #or (epoch_ppv > best_ppv)):
                best_sn = epoch_sn
                best_ppv = epoch_ppv
                best_loss = epoch_loss_training
                best_model_wts = copy.deepcopy(model.state_dict())
                torch.save(best_model_wts, join(output_dir, '{}_{}_{}.pth'.format(best_sn, best_ppv, best_loss)))
                
                print('Weights of model saved at {}'.format(join(output_dir, '{}_{}_{}.pth'.format(best_sn, 
                                                                                                   best_ppv, 
                                                                                                   best_loss))))

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val SN: {:4f}, Best val PPV: {:4f}, Best Loss: {:4f}'.format(best_sn, best_ppv, best_loss))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %% [markdown]
# # Config Model

# %%
model = RefineNet4Cascade((3, image_size), num_classes=1)

criterion = metrics.criterion_fn

# Observe that all parameters are being optimized
#optimizer = optim.SGD(filter(lambda p:  p.requires_grad, model.parameters()), lr=0.001, momentum=0.9)
optimizer = optim.Adam(filter(lambda p:  p.requires_grad, model.parameters()), lr=0.0001)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.1)

# %% [markdown]
# # Train and evaluate

# %%
model_ft = train_model(model, criterion, optimizer, exp_lr_scheduler, num_epochs=50)
# Out:
# Epoch 1/50
# ----------
# train Loss: 1.1694, SN: 0.0000, PPV: nan
# val Loss: 1.0816, SN: 0.0000, PPV: nan
#
# Epoch 2/50
# ----------
# train Loss: 1.0889, SN: 0.0000, PPV: nan
# val Loss: 1.1080, SN: 0.0000, PPV: nan
#
# Epoch 3/50
# ----------
# train Loss: 1.0752, SN: 0.0000, PPV: nan
# val Loss: 1.0529, SN: 0.0000, PPV: nan
#
# Epoch 4/50
# ----------
# train Loss: 1.0138, SN: 0.0000, PPV: nan
# val Loss: 0.9910, SN: 0.0000, PPV: nan
#
# Epoch 5/50
# ----------
# train Loss: 0.9530, SN: 0.0119, PPV: nan
# val Loss: 0.9591, SN: 0.3938, PPV: 0.2942
# Model saved.
#
# Epoch 6/50
# ----------
# train Loss: 0.8866, SN: 0.4064, PPV: 0.3362
# val Loss: 0.9624, SN: 0.7367, PPV: 0.1711
# Model saved.
#
# Epoch 7/50
# ----------
# train Loss: 0.8087, SN: 0.4722, PPV: 0.3646
# val Loss: 0.8272, SN: 0.6512, PPV: 0.2559
# Model saved.
#
# Epoch 8/50
# ----------
# train Loss: 0.8160, SN: 0.4916, PPV: 0.3134
# val Loss: 0.7794, SN: 0.4854, PPV: 0.3670
# Model saved.
#
# Epoch 9/50
# ----------
# train Loss: 0.7599, SN: 0.4715, PPV: nan
# val Loss: 0.7506, SN: 0.5036, PPV: 0.4037
# Model saved.
#
# Epoch 10/50
# ----------
# train Loss: 0.7670, SN: 0.4892, PPV: 0.3721
# val Loss: 0.7482, SN: 0.5988, PPV: 0.2875
# Model saved.
#
# Epoch 11/50
# ----------
# train Loss: 0.7408, SN: 0.5143, PPV: 0.3797
# val Loss: 0.7593, SN: 0.3870, PPV: 0.5472
# Model saved.
#
# Epoch 12/50
# ----------
# train Loss: 0.7294, SN: 0.4974, PPV: 0.4186
# val Loss: 0.7153, SN: 0.5026, PPV: 0.4141
# Model saved.
#
# Epoch 13/50
# ----------
# train Loss: 0.6935, SN: 0.4658, PPV: 0.3859
# val Loss: 0.7150, SN: 0.4588, PPV: 0.4627
# Model saved.
#
# Epoch 14/50
# ----------
# train Loss: 0.6860, SN: 0.4848, PPV: 0.4265
# val Loss: 0.7215, SN: 0.5983, PPV: 0.3451
# Model saved.
#
# Epoch 15/50
# ----------
# train Loss: 0.6794, SN: 0.5030, PPV: 0.4324
# val Loss: 0.7065, SN: 0.6162, PPV: 0.3533
# Model saved.
#
# Epoch 16/50
# ----------
# train Loss: 0.6783, SN: 0.5562, PPV: 0.4216
# val Loss: 0.6782, SN: 0.5365, PPV: 0.4312
# Model saved.
#
# Epoch 17/50
# ----------
# train Loss: 0.6658, SN: 0.5082, PPV: 0.4160
# val Loss: 0.6801, SN: 0.6194, PPV: 0.4182
# Model saved.
#
# Epoch 18/50
# ----------
# train Loss: 0.6609, SN: 0.5349, PPV: 0.4346
# val Loss: 0.6705, SN: 0.5678, PPV: 0.4619
# Model saved.
#
# Epoch 19/50
# ----------
# train Loss: 0.6461, SN: 0.5597, PPV: 0.4207
# val Loss: 0.6666, SN: 0.4519, PPV: 0.3761
#
# Epoch 20/50
# ----------
# train Loss: 0.6555, SN: 0.5368, PPV: 0.4401
# val Loss: 0.6769, SN: 0.5190, PPV: 0.4912
# Model saved.
#
# Epoch 21/50
# ----------
# train Loss: 0.6400, SN: 0.5733, PPV: 0.4402
# val Loss: 0.6711, SN: 0.5713, PPV: 0.4612
# Model saved.
#
# Epoch 22/50
# ----------
# train Loss: 0.6386, SN: 0.5385, PPV: 0.4336
# val Loss: 0.6670, SN: 0.6460, PPV: 0.3997
# Model saved.
#
# Epoch 23/50
# ----------
# train Loss: 0.6355, SN: 0.5503, PPV: 0.4112
# val Loss: 0.6768, SN: 0.5034, PPV: 0.4626
# Model saved.
#
# Epoch 24/50
# ----------
# train Loss: 0.6352, SN: 0.5300, PPV: 0.4250
# val Loss: 0.6713, SN: 0.4331, PPV: 0.5036
# Model saved.
#
# Epoch 25/50
# ----------
# train Loss: 0.6373, SN: 0.5391, PPV: 0.4449
# val Loss: 0.6567, SN: 0.5310, PPV: 0.3385
# Model saved.
#
# Epoch 26/50
# ----------
# train Loss: 0.6395, SN: 0.5664, PPV: 0.4194
# val Loss: 0.6596, SN: 0.4940, PPV: 0.4420
# Model saved.
#
# Epoch 27/50
# ----------
# train Loss: 0.6307, SN: 0.5504, PPV: 0.4438
# val Loss: 0.6593, SN: 0.6498, PPV: 0.4191
# Model saved.
#
# Epoch 28/50
# ----------
# train Loss: 0.6155, SN: 0.5776, PPV: 0.4765
# val Loss: 0.6504, SN: 0.5475, PPV: 0.4132
#
# Epoch 29/50
# ----------
# train Loss: 0.6209, SN: 0.5588, PPV: 0.4697
# val Loss: 0.6565, SN: 0.5742, PPV: 0.4901
# Model saved.
#
# Epoch 30/50
# ----------
# train Loss: 0.6406, SN: 0.5367, PPV: 0.4344
# val Loss: 0.6761, SN: 0.4697, PPV: 0.5832
# Model saved.
#
# Epoch 31/50
# ----------
# train Loss: 0.6275, SN: 0.5529, PPV: 0.4724
# val Loss: 0.6570, SN: 0.5653, PPV: 0.3502
# Model saved.
#
# Epoch 32/50
# ----------
# train Loss: 0.6207, SN: 0.5367, PPV: 0.4610
# val Loss: 0.8839, SN: 0.1849, PPV: 0.7641
# Model saved.
#
# Epoch 33/50
# ----------
# train Loss: 0.6466, SN: 0.5479, PPV: 0.4443
# val Loss: 0.6581, SN: 0.6924, PPV: 0.4113
# Model saved.
#
# Epoch 34/50
# ----------
# train Loss: 0.6328, SN: 0.5654, PPV: 0.4359
# val Loss: 0.6581, SN: 0.4926, PPV: 0.4832
# Model saved.
#
# Epoch 35/50
# ----------
# train Loss: 0.6273, SN: 0.5487, PPV: 0.4779
# val Loss: 0.6459, SN: 0.5282, PPV: 0.4551
# Model saved.
#
# Epoch 36/50
# ----------
# train Loss: 0.6110, SN: 0.5828, PPV: 0.4638
# val Loss: 0.6539, SN: 0.5213, PPV: 0.5130
# Model saved.
#
# Epoch 37/50
# ----------
# train Loss: 0.6208, SN: 0.5327, PPV: 0.4649
# val Loss: 0.6463, SN: 0.6094, PPV: 0.4732
# Model saved.
#
# Epoch 38/50
# ----------
# train Loss: 0.6211, SN: 0.5640, PPV: 0.4678
# val Loss: 0.6522, SN: 0.5363, PPV: 0.4277
#
# Epoch 39/50
# ----------
# train Loss: 0.6246, SN: 0.5383, PPV: 0.4347
# val Loss: 0.6477, SN: 0.5158, PPV: 0.5355
# Model saved.
#
# Epoch 40/50
# ----------
# train Loss: 0.6211, SN: 0.5576, PPV: 0.4541
# val Loss: 0.6743, SN: 0.5432, PPV: 0.2836
# Model saved.
#
# Epoch 41/50
# ----------
# train Loss: 0.6158, SN: 0.5593, PPV: 0.4407
# val Loss: 0.6643, SN: 0.5265, PPV: 0.3258
# Model saved.
#
# Epoch 42/50
# ----------
# train Loss: 0.6218, SN: 0.5840, PPV: 0.4515
# val Loss: 0.6409, SN: 0.5855, PPV: 0.4825
# Model saved.
#
# Epoch 43/50
# ----------
# train Loss: 0.6195, SN: 0.5746, PPV: 0.5021
# val Loss: 0.6451, SN: 0.5098, PPV: 0.4894
# Model saved.
#
# Epoch 44/50
# ----------
# train Loss: 0.6045, SN: 0.5647, PPV: 0.4758
# val Loss: 0.6399, SN: 0.4904, PPV: 0.4214
#
# Epoch 45/50
# ----------
# train Loss: 0.6099, SN: 0.5686, PPV: 0.4559
# val Loss: 0.6515, SN: 0.6139, PPV: 0.3741
# Model saved.
#
# Epoch 46/50
# ----------
# train Loss: 0.6115, SN: 0.5467, PPV: 0.4448
# val Loss: 0.6348, SN: 0.6279, PPV: 0.4568
# Model saved.
#
# Epoch 47/50
# ----------
# train Loss: 0.6075, SN: 0.5709, PPV: 0.4607
# val Loss: 0.6519, SN: 0.5129, PPV: 0.4300
#
# Epoch 48/50
# ----------
# train Loss: 0.6478, SN: 0.5507, PPV: 0.4416
# val Loss: 0.6480, SN: 0.5727, PPV: 0.4678
# Model saved.
#
# Epoch 49/50
# ----------
# train Loss: 0.6452, SN: 0.5325, PPV: 0.4824
# val Loss: 0.7192, SN: 0.7135, PPV: 0.2920
# Model saved.
#
# Epoch 50/50
# ----------
# train Loss: 0.6385, SN: 0.5878, PPV: 0.4540
# val Loss: 0.6428, SN: 0.6047, PPV: 0.4755
# Model saved.
#
# Training complete in 70m 14s
# Best val Acc: 0.604743

# %%
val Loss: 0.6283, SN: 0.5830, PPV: 0.5109

# %%
weightt_path = join(output_dir, '0.6047431260347367_0.4754905641078949_0.6427530169486999.pth')
model_ft.load_state_dict(torch.load(weightt_path))

# %%
optimizer = optim.Adam(filter(lambda p:  p.requires_grad, model.parameters()), lr=0.00001)

# %%
model_ft = train_model(model_ft, criterion, optimizer, exp_lr_scheduler, num_epochs=50)
# Out:
# Epoch 1/50
# ----------
# train Loss: 0.6119, SN: 0.5702, PPV: 0.4913
# val Loss: 0.6415, SN: 0.5039, PPV: 0.4245
# Model saved.
#
# Epoch 2/50
# ----------
# train Loss: 0.6152, SN: 0.5686, PPV: 0.4731
# val Loss: 0.6401, SN: 0.5584, PPV: 0.4814
# Model saved.
#
# Epoch 3/50
# ----------
# train Loss: 0.6061, SN: 0.5679, PPV: 0.5090
# val Loss: 0.6397, SN: 0.5875, PPV: 0.4489
# Model saved.
#
# Epoch 4/50
# ----------
# train Loss: 0.6107, SN: 0.5723, PPV: 0.4784
# val Loss: 0.6371, SN: 0.5289, PPV: 0.4455
#
# Epoch 5/50
# ----------
# train Loss: 0.6113, SN: 0.5653, PPV: 0.4778
# val Loss: 0.6353, SN: 0.5336, PPV: 0.4397
#
# Epoch 6/50
# ----------
# train Loss: 0.5983, SN: 0.5833, PPV: 0.4837
# val Loss: 0.6359, SN: 0.5619, PPV: 0.4655
# Model saved.
#
# Epoch 7/50
# ----------
# train Loss: 0.6045, SN: 0.5247, PPV: 0.4663
# val Loss: 0.6366, SN: 0.6003, PPV: 0.4443
# Model saved.
#
# Epoch 8/50
# ----------
# train Loss: 0.6040, SN: 0.5762, PPV: 0.4611
# val Loss: 0.6350, SN: 0.5338, PPV: 0.4541
# Model saved.
#
# Epoch 9/50
# ----------
# train Loss: 0.6042, SN: 0.5303, PPV: 0.4628
# val Loss: 0.6350, SN: 0.6537, PPV: 0.4542
# Model saved.
#
# Epoch 10/50
# ----------
# train Loss: 0.6053, SN: 0.5458, PPV: 0.4750
# val Loss: 0.6359, SN: 0.5913, PPV: 0.4983
# Model saved.
#
# Epoch 11/50
# ----------
# train Loss: 0.5989, SN: 0.5696, PPV: 0.4678
# val Loss: 0.6350, SN: 0.4843, PPV: 0.4739
#
# Epoch 12/50
# ----------
# train Loss: 0.6072, SN: 0.5596, PPV: 0.4703
# val Loss: 0.6307, SN: 0.5390, PPV: 0.4274
#
# Epoch 13/50
# ----------
# train Loss: 0.5996, SN: 0.5768, PPV: 0.4707
# val Loss: 0.6370, SN: 0.5589, PPV: 0.5385
# Model saved.
#
# Epoch 14/50
# ----------
# train Loss: 0.5995, SN: 0.5876, PPV: 0.4747
# val Loss: 0.6338, SN: 0.5042, PPV: 0.4187
#
# Epoch 15/50
# ----------
# train Loss: 0.5963, SN: 0.5629, PPV: 0.4906
# val Loss: 0.6311, SN: 0.5166, PPV: 0.4479
#
# Epoch 16/50
# ----------
# train Loss: 0.5969, SN: 0.5536, PPV: 0.5043
# val Loss: 0.6303, SN: 0.6044, PPV: 0.4960
# Model saved.
#
# Epoch 17/50
# ----------
# train Loss: 0.6011, SN: 0.5576, PPV: 0.4516
# val Loss: 0.6289, SN: 0.5134, PPV: 0.4498
#
# Epoch 18/50
# ----------
# train Loss: 0.5939, SN: 0.5864, PPV: 0.5014
# val Loss: 0.6312, SN: 0.5751, PPV: 0.5052
# Model saved.
#
# Epoch 19/50
# ----------
# train Loss: 0.6007, SN: 0.5660, PPV: 0.4595
# val Loss: 0.6312, SN: 0.5125, PPV: 0.4819
#
# Epoch 20/50
# ----------
# train Loss: 0.6046, SN: 0.5661, PPV: 0.4912
# val Loss: 0.6312, SN: 0.5490, PPV: 0.5067
# Model saved.
#
# Epoch 21/50
# ----------
# train Loss: 0.6016, SN: 0.5527, PPV: 0.4447
# val Loss: 0.6365, SN: 0.5423, PPV: 0.5390
# Model saved.
#
# Epoch 22/50
# ----------
# train Loss: 0.5968, SN: 0.5358, PPV: 0.4803
# val Loss: 0.6313, SN: 0.5333, PPV: 0.4639
#
# Epoch 23/50
# ----------
# train Loss: 0.5994, SN: 0.5588, PPV: 0.4620
# val Loss: 0.6319, SN: 0.5219, PPV: 0.4824
#
# Epoch 24/50
# ----------
# train Loss: 0.6018, SN: 0.5600, PPV: 0.5087
# val Loss: 0.6327, SN: 0.5619, PPV: 0.4138
# Model saved.
#
# Epoch 25/50
# ----------
# train Loss: 0.5995, SN: 0.5837, PPV: 0.4543
# val Loss: 0.6316, SN: 0.5688, PPV: 0.5180
# Model saved.
#
# Epoch 26/50
# ----------
# train Loss: 0.5902, SN: 0.5697, PPV: 0.4791
# val Loss: 0.6294, SN: 0.5486, PPV: 0.4499
#
# Epoch 27/50
# ----------
# train Loss: 0.6001, SN: 0.5553, PPV: 0.4772
# val Loss: 0.6309, SN: 0.5332, PPV: 0.4804
#
# Epoch 28/50
# ----------
# train Loss: 0.5970, SN: 0.5696, PPV: 0.4849
# val Loss: 0.6285, SN: 0.5823, PPV: 0.4981
# Model saved.
#
# Epoch 29/50
# ----------
# train Loss: 0.5916, SN: 0.5692, PPV: 0.4696
# val Loss: 0.6297, SN: 0.5775, PPV: 0.4649
#
# Epoch 30/50
# ----------
# train Loss: 0.5932, SN: 0.5721, PPV: 0.5152
# val Loss: 0.6312, SN: 0.6611, PPV: 0.4724
# Model saved.
#
# Epoch 31/50
# ----------
# train Loss: 0.5982, SN: 0.5765, PPV: 0.4945
# val Loss: 0.6272, SN: 0.4903, PPV: 0.4185
#
# Epoch 32/50
# ----------
# train Loss: 0.5990, SN: 0.5915, PPV: 0.4910
# val Loss: 0.6325, SN: 0.5704, PPV: 0.5118
# Model saved.
#
# Epoch 33/50
# ----------
# train Loss: 0.5941, SN: 0.5280, PPV: 0.4690
# val Loss: 0.6306, SN: 0.5390, PPV: 0.4694
#
# Epoch 34/50
# ----------
# train Loss: 0.5926, SN: 0.5811, PPV: 0.5065
# val Loss: 0.6286, SN: 0.5710, PPV: 0.4624
# Model saved.
#
# Epoch 35/50
# ----------
# train Loss: 0.5914, SN: 0.5698, PPV: 0.5008
# val Loss: 0.6294, SN: 0.5520, PPV: 0.4762
# Model saved.
#
# Epoch 36/50
# ----------
# train Loss: 0.5975, SN: 0.5784, PPV: 0.4845
# val Loss: 0.6273, SN: 0.6009, PPV: 0.5123
# Model saved.
#
# Epoch 37/50
# ----------
# train Loss: 0.5907, SN: 0.5549, PPV: 0.4905
# val Loss: 0.6321, SN: 0.5338, PPV: 0.4634
#
# Epoch 38/50
# ----------
# train Loss: 0.5854, SN: 0.5754, PPV: 0.4930
# val Loss: 0.6289, SN: 0.6141, PPV: 0.5026
# Model saved.
#
# Epoch 39/50
# ----------
# train Loss: 0.5970, SN: 0.5644, PPV: 0.4816
# val Loss: 0.6274, SN: 0.6077, PPV: 0.5005
#
# Epoch 40/50
# ----------
# train Loss: 0.5882, SN: 0.5745, PPV: 0.4780
# val Loss: 0.6326, SN: 0.5478, PPV: 0.4980
#
# Epoch 41/50
# ----------
# train Loss: 0.5872, SN: 0.5891, PPV: 0.4904
# val Loss: 0.6287, SN: 0.5427, PPV: 0.4723
#
# Epoch 42/50
# ----------
# train Loss: 0.5894, SN: 0.5304, PPV: 0.4699
# val Loss: 0.6280, SN: 0.5787, PPV: 0.4587
#
# Epoch 43/50
# ----------
# train Loss: 0.5908, SN: 0.5760, PPV: 0.4836
# val Loss: 0.6299, SN: 0.5547, PPV: 0.4753
#
# Epoch 44/50
# ----------
# train Loss: 0.5904, SN: 0.5520, PPV: 0.4652
# val Loss: 0.6273, SN: 0.4567, PPV: 0.3884
#
# Epoch 45/50
# ----------
# train Loss: 0.5959, SN: 0.5911, PPV: 0.5068
# val Loss: 0.6273, SN: 0.5471, PPV: 0.4386
#
# Epoch 46/50
# ----------
# train Loss: 0.5904, SN: 0.5920, PPV: 0.5071
# val Loss: 0.6283, SN: 0.5830, PPV: 0.5109
# Model saved.
#
# Epoch 47/50
# ----------
# train Loss: 0.5858, SN: 0.5812, PPV: 0.4863
# val Loss: 0.6305, SN: 0.5168, PPV: 0.4564
#
# Epoch 48/50
# ----------
# train Loss: 0.5887, SN: 0.5609, PPV: 0.4861
# val Loss: 0.6282, SN: 0.5815, PPV: 0.4621
#
# Epoch 49/50
# ----------
# train Loss: 0.5870, SN: 0.5734, PPV: 0.4969
# val Loss: 0.6277, SN: 0.5613, PPV: 0.4738
#
# Epoch 50/50
# ----------
# train Loss: 0.5898, SN: 0.5628, PPV: 0.4752
# val Loss: 0.6275, SN: 0.5319, PPV: 0.4701
#
# Training complete in 71m 45s
# Best val Acc: 0.583035

# %%
model = RefineNet4Cascade((3, image_size), num_classes=1, freeze_resnet=False)
optimizer = optim.Adam(filter(lambda p:  p.requires_grad, model.parameters()), lr=0.0001)
weightt_path = join(output_dir, '0.5830354124307633_0.5109297752380371_0.6283033072948456.pth')
model.load_state_dict(torch.load(weightt_path))

# %%
model_ft = train_model(model, criterion, optimizer, exp_lr_scheduler, num_epochs=50)
# Out:
# Epoch 1/50
# ----------
# train Loss: 0.6432, SN: 0.5648, PPV: 0.4868
# val Loss: 0.6374, SN: 0.6200, PPV: 0.4946
# Weights of model saved at ./weights/0.6199580252170562_0.494629842042923_0.6373553276062012.pth
#
# Epoch 2/50
# ----------
# train Loss: 0.6160, SN: 0.5461, PPV: 0.4653
# val Loss: 0.6330, SN: 0.4621, PPV: 0.4363
#
# Epoch 3/50
# ----------
# train Loss: 0.6113, SN: 0.5538, PPV: 0.4614
# val Loss: 0.6324, SN: 0.5066, PPV: 0.4503
#
# Epoch 4/50
# ----------
# train Loss: 0.6037, SN: 0.5719, PPV: 0.4780
# val Loss: 0.6308, SN: 0.4883, PPV: 0.3858
#
# Epoch 5/50
# ----------
# train Loss: 0.6052, SN: 0.5680, PPV: 0.4607
# val Loss: 0.6375, SN: 0.6131, PPV: 0.3824
#
# Epoch 6/50
# ----------
# train Loss: 0.6020, SN: 0.5885, PPV: 0.4979
# val Loss: 0.6324, SN: 0.5598, PPV: 0.3695
#
# Epoch 7/50
# ----------
# train Loss: 0.5958, SN: 0.5734, PPV: 0.4877
# val Loss: 0.6294, SN: 0.5746, PPV: 0.4863
#
# Epoch 8/50
# ----------
# train Loss: 0.5952, SN: 0.5847, PPV: 0.4972
# val Loss: 0.6293, SN: 0.5741, PPV: 0.4704
#
# Epoch 9/50
# ----------
# train Loss: 0.5957, SN: 0.5658, PPV: 0.4771
# val Loss: 0.6319, SN: 0.5334, PPV: 0.5237
# Weights of model saved at ./weights/0.5334106087684631_0.5236914604902267_0.6319295823574066.pth
#
# Epoch 10/50
# ----------
# train Loss: 0.5940, SN: 0.5680, PPV: 0.5028
# val Loss: 0.6284, SN: 0.5767, PPV: 0.4294
# Weights of model saved at ./weights/0.5766574531793595_0.4294485509395599_0.6284426391124726.pth
#
# Epoch 11/50
# ----------
# train Loss: 0.5847, SN: 0.5641, PPV: 0.4989
# val Loss: 0.6302, SN: 0.5685, PPV: 0.4941
# Weights of model saved at ./weights/0.5684650242328644_0.4941275954246521_0.6302417635917663.pth
#
# Epoch 12/50
# ----------
# train Loss: 0.6133, SN: 0.5376, PPV: 0.4405
# val Loss: 0.6318, SN: 0.6337, PPV: 0.4927
# Weights of model saved at ./weights/0.6337360620498658_0.4926973819732666_0.6317687928676605.pth
#
# Epoch 13/50
# ----------
# train Loss: 0.6046, SN: 0.5766, PPV: 0.5075
# val Loss: 0.6298, SN: 0.6228, PPV: 0.5004
# Weights of model saved at ./weights/0.6227556049823761_0.5004052132368088_0.6297641634941101.pth
#
# Epoch 14/50
# ----------
# train Loss: 0.5999, SN: 0.5814, PPV: 0.4739
# val Loss: 0.6585, SN: 0.3886, PPV: 0.5116
# Weights of model saved at ./weights/0.38856889605522155_0.5116120606660843_0.6584696888923645.pth
#
# Epoch 15/50
# ----------
# train Loss: 0.5926, SN: 0.5500, PPV: 0.4940
# val Loss: 0.6336, SN: 0.6498, PPV: 0.4201
# Weights of model saved at ./weights/0.6498402535915375_0.420136484503746_0.6336001098155976.pth
#
# Epoch 16/50
# ----------
# train Loss: 0.5941, SN: 0.5769, PPV: 0.4856
# val Loss: 0.6308, SN: 0.6204, PPV: 0.4265
# Weights of model saved at ./weights/0.6203920423984528_0.4265142746269703_0.6307753682136535.pth
#
# Epoch 17/50
# ----------
# train Loss: 0.5909, SN: 0.5829, PPV: 0.4957
# val Loss: 0.6288, SN: 0.6280, PPV: 0.4662
# Weights of model saved at ./weights/0.6279992282390594_0.46617298722267153_0.6288009941577911.pth
#
# Epoch 18/50
# ----------
# train Loss: 0.5836, SN: 0.5449, PPV: 0.5152
# val Loss: 0.6355, SN: 0.5848, PPV: 0.3903
#
# Epoch 19/50
# ----------
# train Loss: 0.6066, SN: 0.5859, PPV: 0.4746
# val Loss: 0.6434, SN: 0.5670, PPV: 0.5339
# Weights of model saved at ./weights/0.5669760853052139_0.5339485615491867_0.643402761220932.pth
#
# Epoch 20/50
# ----------
# train Loss: 0.6026, SN: 0.5399, PPV: 0.5069
# val Loss: 0.6414, SN: 0.5928, PPV: 0.4373
# Weights of model saved at ./weights/0.5928270310163498_0.43731013536453245_0.6414147436618804.pth
#
# Epoch 21/50
# ----------
# train Loss: 0.5910, SN: 0.5675, PPV: 0.4607
# val Loss: 0.6271, SN: 0.4954, PPV: 0.4151
#
# Epoch 22/50
# ----------
# train Loss: 0.5804, SN: 0.5777, PPV: 0.4880
# val Loss: 0.6288, SN: 0.5486, PPV: 0.4440
# Weights of model saved at ./weights/0.5486212134361267_0.4440338045358658_0.6287867307662964.pth
#
# Epoch 23/50
# ----------
# train Loss: 0.5802, SN: 0.6011, PPV: 0.4972
# val Loss: 0.6277, SN: 0.5217, PPV: 0.4790
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-20-9582bee0122b> in <module>()
# ----> 1 model_ft = train_model(model, criterion, optimizer, exp_lr_scheduler, num_epochs=50)
#
# <ipython-input-18-04905489c3aa> in train_model(model, criterion, optimizer, scheduler, num_epochs, threshold)
#      74                 best_loss = epoch_loss_training
#      75                 best_model_wts = copy.deepcopy(model.state_dict())
# ---> 76                 torch.save(best_model_wts, join(output_dir, '{}_{}_{}.pth'.format(best_sn, best_ppv, best_loss)))
#      77
#      78                 print('Weights of model saved at {}'.format(join(output_dir, '{}_{}_{}.pth'.format(best_sn,
#
# ~/anaconda3/envs/deep1/lib/python3.6/site-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol)
#     133         pickle_protocol: can be specified to override the default protocol
#     134     """
# --> 135     return _with_file_like(f, "wb", lambda f: _save(obj, f, pickle_module, pickle_protocol))
#     136
#     137
#
# ~/anaconda3/envs/deep1/lib/python3.6/site-packages/torch/serialization.py in _with_file_like(f, mode, body)
#     115         f = open(f, mode)
#     116     try:
# --> 117         return body(f)
#     118     finally:
#     119         if new_fd:
#
# ~/anaconda3/envs/deep1/lib/python3.6/site-packages/torch/serialization.py in <lambda>(f)
#     133         pickle_protocol: can be specified to override the default protocol
#     134     """
# --> 135     return _with_file_like(f, "wb", lambda f: _save(obj, f, pickle_module, pickle_protocol))
#     136
#     137
#
# ~/anaconda3/envs/deep1/lib/python3.6/site-packages/torch/serialization.py in _save(obj, f, pickle_module, pickle_protocol)
#     202     f.flush()
#     203     for key in serialized_storage_keys:
# --> 204         serialized_storages[key]._write_file(f)
#     205
#     206
#
# RuntimeError: Unknown error -1

# %%
model = RefineNet4Cascade((3, image_size), num_classes=1, freeze_resnet=False)
optimizer = optim.Adam(filter(lambda p:  p.requires_grad, model.parameters()), lr=0.0001)
weightt_path = join(output_dir, '0.6279992282390594_0.46617298722267153_0.6288009941577911.pth')
model.load_state_dict(torch.load(weightt_path))

# %%
model_ft = train_model(model, criterion, optimizer, exp_lr_scheduler, num_epochs=50)
# Out:
# Epoch 1/50
# ----------
# train Loss: 0.6261, SN: 0.5589, PPV: 0.4849
# val Loss: 0.6338, SN: 0.5399, PPV: 0.4405
# Weights of model saved at ./weights/0.539866840839386_0.44053341150283815_0.6337691128253937.pth
#
# Epoch 2/50
# ----------
# train Loss: 0.6269, SN: 0.5386, PPV: 0.4749
# val Loss: 0.6386, SN: 0.5648, PPV: 0.3804
# Weights of model saved at ./weights/0.5648127913475036_0.38043809980154036_0.6386163771152497.pth
#
# Epoch 3/50
# ----------
# train Loss: 0.6165, SN: 0.5395, PPV: 0.4521
# val Loss: 0.6362, SN: 0.6521, PPV: 0.4246
# Weights of model saved at ./weights/0.6521024376153945_0.42463904321193696_0.6361688792705535.pth
#
# Epoch 4/50
# ----------
# train Loss: 0.6141, SN: 0.5448, PPV: 0.4771
# val Loss: 0.6502, SN: 0.6902, PPV: 0.4063
# Weights of model saved at ./weights/0.6901501536369323_0.4063425987958908_0.6501660764217376.pth
#
# Epoch 5/50
# ----------
# train Loss: 0.6101, SN: 0.5907, PPV: 0.4657
# val Loss: 0.6294, SN: 0.5095, PPV: 0.4016
#
# Epoch 6/50
# ----------
# train Loss: 0.6136, SN: 0.5518, PPV: 0.4971
# val Loss: 0.6445, SN: 0.6913, PPV: 0.4422
# Weights of model saved at ./weights/0.6913297057151795_0.44222467839717866_0.6444911777973175.pth
#
# Epoch 7/50
# ----------
# train Loss: 0.6188, SN: 0.5694, PPV: 0.4904
# val Loss: 0.6419, SN: 0.5055, PPV: 0.5420
# Weights of model saved at ./weights/0.5054926186800003_0.5420256584882737_0.6419490218162537.pth
#
# Epoch 8/50
# ----------
# train Loss: 0.6025, SN: 0.5474, PPV: 0.5048
# val Loss: 0.6308, SN: 0.6376, PPV: 0.4657
# Weights of model saved at ./weights/0.637614506483078_0.4657466888427734_0.6307955503463745.pth
#
# Epoch 9/50
# ----------
# train Loss: 0.6147, SN: 0.5782, PPV: 0.4805
# val Loss: 0.6356, SN: 0.6002, PPV: 0.4003
#
# Epoch 10/50
# ----------
# train Loss: 0.5966, SN: 0.6023, PPV: 0.5030
# val Loss: 0.6288, SN: 0.6179, PPV: 0.4387
#
# Epoch 11/50
# ----------
# train Loss: 0.6004, SN: 0.5824, PPV: 0.4709
# val Loss: 0.6278, SN: 0.5188, PPV: 0.4664
# Weights of model saved at ./weights/0.5187769204378128_0.4664010047912598_0.6278474032878876.pth
#
# Epoch 12/50
# ----------
# train Loss: 0.5977, SN: 0.5663, PPV: 0.4904
# val Loss: 0.6313, SN: 0.6482, PPV: 0.4591
# Weights of model saved at ./weights/0.6481563210487366_0.4590709149837494_0.6312629878520966.pth
#
# Epoch 13/50
# ----------
# train Loss: 0.5869, SN: 0.5709, PPV: 0.4884
# val Loss: 0.6260, SN: 0.5969, PPV: 0.4905
# Weights of model saved at ./weights/0.5968587398529053_0.49047706425189974_0.6260455071926116.pth
#
# Epoch 14/50
# ----------
# train Loss: 0.5873, SN: 0.5870, PPV: 0.4909
# val Loss: 0.6239, SN: 0.4951, PPV: 0.4062
#
# Epoch 15/50
# ----------
# train Loss: 0.5869, SN: 0.5806, PPV: 0.4777
# val Loss: 0.6245, SN: 0.4935, PPV: 0.4666
#
# Epoch 16/50
# ----------
# train Loss: 0.5863, SN: 0.5777, PPV: 0.4693
# val Loss: 0.6269, SN: 0.5515, PPV: 0.5317
# Weights of model saved at ./weights/0.551509964466095_0.5316934943199157_0.6268541514873505.pth
#
# Epoch 17/50
# ----------
# train Loss: 0.5866, SN: 0.5653, PPV: 0.4866
# val Loss: 0.6245, SN: 0.4911, PPV: 0.4371
#
# Epoch 18/50
# ----------
# train Loss: 0.5822, SN: 0.5938, PPV: 0.4943
# val Loss: 0.6272, SN: 0.6340, PPV: 0.4516
# Weights of model saved at ./weights/0.6339931160211563_0.45159670412540437_0.6271971642971039.pth
#
# Epoch 19/50
# ----------
# train Loss: 0.5838, SN: 0.5839, PPV: 0.4657
# val Loss: 0.6281, SN: 0.5808, PPV: 0.5088
# Weights of model saved at ./weights/0.5808408111333847_0.5087937206029892_0.6280714273452759.pth
#
# Epoch 20/50
# ----------
# train Loss: 0.5843, SN: 0.5785, PPV: 0.5253
# val Loss: 0.6265, SN: 0.5737, PPV: 0.4605
#
# Epoch 21/50
# ----------
# train Loss: 0.5882, SN: 0.5782, PPV: 0.4821
# val Loss: 0.6428, SN: 0.6211, PPV: 0.4280
# Weights of model saved at ./weights/0.6211087346076966_0.4280376434326172_0.6427858412265778.pth
#
# Epoch 22/50
# ----------
# train Loss: 0.5876, SN: 0.5777, PPV: 0.4671
# val Loss: 0.6259, SN: 0.6193, PPV: 0.4947
# Weights of model saved at ./weights/0.619310176372528_0.49473459720611573_0.6258914947509766.pth
#
# Epoch 23/50
# ----------
# train Loss: 0.5826, SN: 0.5476, PPV: 0.4622
# val Loss: 0.6370, SN: 0.5773, PPV: 0.4731
#
# Epoch 24/50
# ----------
# train Loss: 0.5852, SN: 0.5735, PPV: 0.5019
# val Loss: 0.6260, SN: 0.6203, PPV: 0.4440
# Weights of model saved at ./weights/0.6202688261866569_0.4439534664154053_0.6260159552097321.pth
#
# Epoch 25/50
# ----------
# train Loss: 0.5768, SN: 0.5827, PPV: 0.5085
# val Loss: 0.6281, SN: 0.6532, PPV: 0.4602
# Weights of model saved at ./weights/0.6532200932502746_0.46022185385227204_0.6280846893787384.pth
#
# Epoch 26/50
# ----------
# train Loss: 0.5803, SN: 0.5587, PPV: 0.4818
# val Loss: 0.6217, SN: 0.5915, PPV: 0.5026
# Weights of model saved at ./weights/0.5915334820747375_0.5026311099529266_0.6217159926891327.pth
#
# Epoch 27/50
# ----------
# train Loss: 0.5761, SN: 0.5767, PPV: 0.5034
# val Loss: 0.6258, SN: 0.5166, PPV: 0.4569
#
# Epoch 28/50
# ----------
# train Loss: 0.5850, SN: 0.5526, PPV: 0.5132
# val Loss: 0.6288, SN: 0.6331, PPV: 0.4748
# Weights of model saved at ./weights/0.6330649256706238_0.4748107433319092_0.628754836320877.pth
#
# Epoch 29/50
# ----------
# train Loss: 0.5855, SN: 0.5887, PPV: 0.5152
# val Loss: 0.6302, SN: 0.6864, PPV: 0.4590
# Weights of model saved at ./weights/0.6864422917366028_0.4589834749698639_0.6301769018173218.pth
#
# Epoch 30/50
# ----------
# train Loss: 0.5776, SN: 0.5801, PPV: 0.5025
# val Loss: 0.6262, SN: 0.6168, PPV: 0.4745
# Weights of model saved at ./weights/0.6167854785919189_0.474493083357811_0.6261587083339691.pth
#
# Epoch 31/50
# ----------
# train Loss: 0.5767, SN: 0.5824, PPV: 0.5001
# val Loss: 0.6350, SN: 0.5764, PPV: 0.4616
#
# Epoch 32/50
# ----------
# train Loss: 0.5845, SN: 0.5625, PPV: 0.4918
# val Loss: 0.6235, SN: 0.5008, PPV: 0.4017
#
# Epoch 33/50
# ----------
# train Loss: 0.5754, SN: 0.5806, PPV: 0.4780
# val Loss: 0.6272, SN: 0.5924, PPV: 0.4777
# Weights of model saved at ./weights/0.5924441948533058_0.4776786595582962_0.6271762013435364.pth
#
# Epoch 34/50
# ----------
# train Loss: 0.5736, SN: 0.5957, PPV: 0.5070
# val Loss: 0.6427, SN: 0.4704, PPV: 0.5133
# Weights of model saved at ./weights/0.47039486169815065_0.5133487313985825_0.642713087797165.pth
#
# Epoch 35/50
# ----------
# train Loss: 0.5727, SN: 0.5547, PPV: 0.4840
# val Loss: 0.6229, SN: 0.5755, PPV: 0.5151
# Weights of model saved at ./weights/0.575476399064064_0.5150630652904511_0.6229429721832276.pth
#
# Epoch 36/50
# ----------
# train Loss: 0.5797, SN: 0.5877, PPV: 0.5038
# val Loss: 0.6335, SN: 0.5487, PPV: 0.5361
# Weights of model saved at ./weights/0.5486772000789643_0.5361497193574906_0.6335058808326721.pth
#
# Epoch 37/50
# ----------
# train Loss: 0.5842, SN: 0.5917, PPV: 0.5182
# val Loss: 0.6297, SN: 0.5895, PPV: 0.4068
# Weights of model saved at ./weights/0.5895430535078049_0.4067601352930069_0.6296827614307403.pth
#
# Epoch 38/50
# ----------
# train Loss: 0.5802, SN: 0.5741, PPV: 0.4945
# val Loss: 0.6356, SN: 0.5299, PPV: 0.5050
# Weights of model saved at ./weights/0.5298708856105805_0.5049580693244934_0.6356334626674652.pth
#
# Epoch 39/50
# ----------
# train Loss: 0.5760, SN: 0.5711, PPV: 0.5048
# val Loss: 0.6246, SN: 0.6103, PPV: 0.5101
# Weights of model saved at ./weights/0.6103249788284302_0.5101222574710846_0.6245980858802795.pth
#
# Epoch 40/50
# ----------
# train Loss: 0.5704, SN: 0.5775, PPV: 0.5137
# val Loss: 0.6268, SN: 0.6747, PPV: 0.4587
# Weights of model saved at ./weights/0.6747364938259125_0.4586836189031601_0.6267801344394683.pth
#
# Epoch 41/50
# ----------
# train Loss: 0.5708, SN: 0.5960, PPV: 0.4930
# val Loss: 0.6281, SN: 0.5263, PPV: 0.4731
# Weights of model saved at ./weights/0.5263337552547455_0.47305515706539153_0.6281465083360672.pth
#
# Epoch 42/50
# ----------
# train Loss: 0.5703, SN: 0.5986, PPV: 0.5314
# val Loss: 0.6237, SN: 0.5784, PPV: 0.4809
# Weights of model saved at ./weights/0.5783548533916474_0.4809322491288185_0.6237143874168396.pth
#
# Epoch 43/50
# ----------
# train Loss: 0.5690, SN: 0.5772, PPV: 0.5107
# val Loss: 0.6369, SN: 0.4577, PPV: 0.5256
# Weights of model saved at ./weights/0.4576930433511734_0.5255719423294067_0.6369118332862854.pth
#
# Epoch 44/50
# ----------
# train Loss: 0.5768, SN: 0.5866, PPV: 0.5084
# val Loss: 0.6241, SN: 0.4970, PPV: 0.4469
# Weights of model saved at ./weights/0.4970014564692974_0.44690470919013026_0.6241201877593994.pth
#
# Epoch 45/50
# ----------
# train Loss: 0.5669, SN: 0.5757, PPV: 0.5223
# val Loss: 0.6317, SN: 0.7004, PPV: 0.4512
# Weights of model saved at ./weights/0.7004039406776428_0.45115841627120973_0.6317032456398011.pth
#
# Epoch 46/50
# ----------
# train Loss: 0.5712, SN: 0.5936, PPV: 0.5071
# val Loss: 0.6254, SN: 0.5844, PPV: 0.5156
# Weights of model saved at ./weights/0.5843683540821075_0.5155929118394852_0.6254106640815735.pth
#
# Epoch 47/50
# ----------
# train Loss: 0.5665, SN: 0.5834, PPV: 0.4929
# val Loss: 0.6472, SN: 0.3947, PPV: 0.5478
# Weights of model saved at ./weights/0.39465825706720353_0.5477960288524628_0.6472209334373474.pth
#
# Epoch 48/50
# ----------
# train Loss: 0.5747, SN: 0.5544, PPV: 0.5250
# val Loss: 0.6262, SN: 0.5406, PPV: 0.3889
# Weights of model saved at ./weights/0.5405613616108894_0.38887912333011626_0.626153975725174.pth
#
# Epoch 49/50
# ----------
# train Loss: 0.5728, SN: 0.5677, PPV: 0.4815
# val Loss: 0.6209, SN: 0.5285, PPV: 0.4679
# Weights of model saved at ./weights/0.5284724712371827_0.4679022580385208_0.6208513081073761.pth
#
# Epoch 50/50
# ----------
# train Loss: 0.5666, SN: 0.5900, PPV: 0.5176
# val Loss: 0.6182, SN: 0.5426, PPV: 0.4932
# Weights of model saved at ./weights/0.542623570561409_0.49317572712898256_0.6181977927684784.pth
#
# Training complete in 74m 5s
# Best val SN: 0.542624, Best val PPV: 0.493176, Best Loss: 0.618198

# %%
model = RefineNet4Cascade((3, image_size), num_classes=1, freeze_resnet=False)
optimizer = optim.Adam(filter(lambda p:  p.requires_grad, model.parameters()), lr=0.0001)
weightt_path = join(output_dir, '0.7004039406776428_0.45115841627120973_0.6317032456398011.pth')
model.load_state_dict(torch.load(weightt_path))

# %%
model_ft = train_model(model, criterion, optimizer, exp_lr_scheduler, num_epochs=100)
# Out:
# Epoch 1/100
# ----------
# train Loss: 0.5909, SN: 0.5667, PPV: 0.4738
# val Loss: 0.6284, SN: 0.5942, PPV: 0.4356
# Weights of model saved at ./weights/0.5942043602466583_0.43559148609638215_0.6284456193447113.pth
#
# Epoch 2/100
# ----------
# train Loss: 0.5919, SN: 0.5647, PPV: 0.4825
# val Loss: 0.6254, SN: 0.6444, PPV: 0.5038
# Weights of model saved at ./weights/0.6443693816661835_0.5037580877542496_0.6254413455724717.pth
#
# Epoch 3/100
# ----------
# train Loss: 0.5897, SN: 0.5926, PPV: 0.4948
# val Loss: 0.6206, SN: 0.5345, PPV: 0.4637
#
# Epoch 4/100
# ----------
# train Loss: 0.5773, SN: 0.5934, PPV: 0.5070
# val Loss: 0.6206, SN: 0.5615, PPV: 0.4550
#
# Epoch 5/100
# ----------
# train Loss: 0.5910, SN: 0.5447, PPV: 0.4733
# val Loss: 0.6443, SN: 0.5329, PPV: 0.3458
#
# Epoch 6/100
# ----------
# train Loss: 0.5994, SN: 0.5876, PPV: 0.4493
# val Loss: 0.6241, SN: 0.5844, PPV: 0.4359
#
# Epoch 7/100
# ----------
# train Loss: 0.5835, SN: 0.5800, PPV: 0.4927
# val Loss: 0.6227, SN: 0.5199, PPV: 0.4835
#
# Epoch 8/100
# ----------
# train Loss: 0.5869, SN: 0.5652, PPV: 0.4858
# val Loss: 0.6231, SN: 0.5739, PPV: 0.4048
#
# Epoch 9/100
# ----------
# train Loss: 0.5867, SN: 0.5805, PPV: 0.4844
# val Loss: 0.6246, SN: 0.5243, PPV: 0.5018
#
# Epoch 10/100
# ----------
# train Loss: 0.5784, SN: 0.5654, PPV: 0.5031
# val Loss: 0.6214, SN: 0.6131, PPV: 0.4677
#
# Epoch 11/100
# ----------
# train Loss: 0.5759, SN: 0.5921, PPV: 0.4954
# val Loss: 0.6236, SN: 0.4983, PPV: 0.4876
#
# Epoch 12/100
# ----------
# train Loss: 0.5722, SN: 0.5838, PPV: 0.5099
# val Loss: 0.6264, SN: 0.5324, PPV: 0.5187
#
# Epoch 13/100
# ----------
# train Loss: 0.5825, SN: 0.5598, PPV: 0.5093
# val Loss: 0.6218, SN: 0.5812, PPV: 0.4590
#
# Epoch 14/100
# ----------
# train Loss: 0.5780, SN: 0.5848, PPV: 0.5001
# val Loss: 0.6233, SN: 0.5331, PPV: 0.4712
#
# Epoch 15/100
# ----------
# train Loss: 0.5778, SN: 0.5660, PPV: 0.4927
# val Loss: 0.6252, SN: 0.5921, PPV: 0.5054
#
# Epoch 16/100
# ----------
# train Loss: 0.5797, SN: 0.5820, PPV: 0.4975
# val Loss: 0.6202, SN: 0.5102, PPV: 0.4918
#
# Epoch 17/100
# ----------
# train Loss: 0.5876, SN: 0.5802, PPV: 0.4896
# val Loss: 0.6195, SN: 0.4963, PPV: 0.4914
#
# Epoch 18/100
# ----------
# train Loss: 0.5850, SN: 0.5714, PPV: 0.4875
# val Loss: 0.6240, SN: 0.5849, PPV: 0.4752
#
# Epoch 19/100
# ----------
# train Loss: 0.5768, SN: 0.5593, PPV: 0.4917
# val Loss: 0.6192, SN: 0.6488, PPV: 0.4820
# Weights of model saved at ./weights/0.6488216996192933_0.48197387158870697_0.6191966772079468.pth
#
# Epoch 20/100
# ----------
# train Loss: 0.5840, SN: 0.5752, PPV: 0.4796
# val Loss: 0.6197, SN: 0.4783, PPV: 0.4846
#
# Epoch 21/100
# ----------
# train Loss: 0.5774, SN: 0.5867, PPV: 0.4986
# val Loss: 0.6577, SN: 0.4922, PPV: 0.5686
#
# Epoch 22/100
# ----------
# train Loss: 0.5841, SN: 0.5512, PPV: 0.5041
# val Loss: 0.6270, SN: 0.5805, PPV: 0.4294
#
# Epoch 23/100
# ----------
# train Loss: 0.5908, SN: 0.5577, PPV: 0.4499
# val Loss: 0.6564, SN: 0.5139, PPV: 0.5604
#
# Epoch 24/100
# ----------
# train Loss: 0.6219, SN: 0.5122, PPV: 0.4546
# val Loss: 0.6629, SN: 0.5066, PPV: 0.5543
#
# Epoch 25/100
# ----------
# train Loss: 0.5982, SN: 0.5650, PPV: 0.5031
# val Loss: 0.6327, SN: 0.5392, PPV: 0.5477
#
# Epoch 26/100
# ----------
# train Loss: 0.5989, SN: 0.5551, PPV: 0.4844
# val Loss: 0.6206, SN: 0.5607, PPV: 0.4427
#
# Epoch 27/100
# ----------
# train Loss: 0.6019, SN: 0.5527, PPV: 0.4276
# val Loss: 0.6380, SN: 0.5738, PPV: 0.4487
#
# Epoch 28/100
# ----------
# train Loss: 0.6071, SN: 0.5661, PPV: 0.4686
# val Loss: 0.6420, SN: 0.6239, PPV: 0.3872
#
# Epoch 29/100
# ----------
# train Loss: 0.6207, SN: 0.5652, PPV: 0.4472
# val Loss: 0.6330, SN: 0.6236, PPV: 0.4502
#
# Epoch 30/100
# ----------
# train Loss: 0.5967, SN: 0.5773, PPV: 0.4815
# val Loss: 0.6286, SN: 0.5466, PPV: 0.4325
#
# Epoch 31/100
# ----------
# train Loss: 0.5931, SN: 0.5675, PPV: 0.4732
# val Loss: 0.6340, SN: 0.4422, PPV: 0.5084
#
# Epoch 32/100
# ----------
# train Loss: 0.5902, SN: 0.5734, PPV: 0.5030
# val Loss: 0.6307, SN: 0.5917, PPV: 0.3862
#
# Epoch 33/100
# ----------
# train Loss: 0.6044, SN: 0.5588, PPV: 0.4646
# val Loss: 0.6512, SN: 0.4400, PPV: 0.5146
#
# Epoch 34/100
# ----------
# train Loss: 0.5882, SN: 0.5663, PPV: 0.5067
# val Loss: 0.6219, SN: 0.4722, PPV: 0.4325
#
# Epoch 35/100
# ----------
# train Loss: 0.5924, SN: 0.5708, PPV: 0.4685
# val Loss: 0.6209, SN: 0.5769, PPV: 0.5149
#
# Epoch 36/100
# ----------
# train Loss: 0.5805, SN: 0.5620, PPV: 0.4903
# val Loss: 0.6244, SN: 0.4970, PPV: 0.4363
#
# Epoch 37/100
# ----------
# train Loss: 0.5873, SN: 0.5807, PPV: 0.4868
# val Loss: 0.6245, SN: 0.5008, PPV: 0.4448
#
# Epoch 38/100
# ----------
# train Loss: 0.5887, SN: 0.5860, PPV: 0.4995
# val Loss: 0.6274, SN: 0.5047, PPV: 0.5532
#
# Epoch 39/100
# ----------
# train Loss: 0.5849, SN: 0.5595, PPV: 0.4697
# val Loss: 0.6505, SN: 0.4394, PPV: 0.5347
#
# Epoch 40/100
# ----------
# train Loss: 0.5877, SN: 0.5582, PPV: 0.4971
# val Loss: 0.6232, SN: 0.5058, PPV: 0.4468
#
# Epoch 41/100
# ----------
# train Loss: 0.5871, SN: 0.5603, PPV: 0.4794
# val Loss: 0.6223, SN: 0.6262, PPV: 0.4862
#
# Epoch 42/100
# ----------
# train Loss: 0.5919, SN: 0.5623, PPV: 0.4800
# val Loss: 0.6346, SN: 0.5095, PPV: 0.5414
#
# Epoch 43/100
# ----------
# train Loss: 0.5959, SN: 0.5356, PPV: 0.5061
# val Loss: 0.6461, SN: 0.5565, PPV: 0.4744
#
# Epoch 44/100
# ----------
# train Loss: 0.5862, SN: 0.5677, PPV: 0.4631
# val Loss: 0.6616, SN: 0.5025, PPV: 0.5806
#
# Epoch 45/100
# ----------
# train Loss: 0.6032, SN: 0.5430, PPV: 0.4872
# val Loss: 0.6310, SN: 0.6067, PPV: 0.4500
#
# Epoch 46/100
# ----------
# train Loss: 0.5879, SN: 0.5688, PPV: 0.4661
# val Loss: 0.6337, SN: 0.6482, PPV: 0.4749
#
# Epoch 47/100
# ----------
# train Loss: 0.5870, SN: 0.5614, PPV: 0.4701
# val Loss: 0.6188, SN: 0.5815, PPV: 0.4592
#
# Epoch 48/100
# ----------
# train Loss: 0.5776, SN: 0.6078, PPV: 0.5138
# val Loss: 0.6201, SN: 0.5096, PPV: 0.4662
#
# Epoch 49/100
# ----------
# train Loss: 0.5797, SN: 0.5596, PPV: 0.4759
# val Loss: 0.6254, SN: 0.5973, PPV: 0.5185
#
# Epoch 50/100
# ----------
# train Loss: 0.5825, SN: 0.5844, PPV: 0.5144
# val Loss: 0.6201, SN: 0.5957, PPV: 0.5154
#
# Epoch 51/100
# ----------
# train Loss: 0.5782, SN: 0.5712, PPV: 0.4956
# val Loss: 0.6226, SN: 0.6164, PPV: 0.4904
#
# Epoch 52/100
# ----------
# train Loss: 0.5780, SN: 0.5836, PPV: 0.4901
# val Loss: 0.6243, SN: 0.5849, PPV: 0.4437
#
# Epoch 53/100
# ----------
# train Loss: 0.5777, SN: 0.5763, PPV: 0.4610
# val Loss: 0.6199, SN: 0.5836, PPV: 0.5158
#
# Epoch 54/100
# ----------
# train Loss: 0.5751, SN: 0.5934, PPV: 0.5110
# val Loss: 0.6165, SN: 0.5877, PPV: 0.5041
#
# Epoch 55/100
# ----------
# train Loss: 0.5761, SN: 0.5790, PPV: 0.5072
# val Loss: 0.6222, SN: 0.5584, PPV: 0.4135
#
# Epoch 56/100
# ----------
# train Loss: 0.5692, SN: 0.6067, PPV: 0.5026
# val Loss: 0.6258, SN: 0.6357, PPV: 0.5077
#
# Epoch 57/100
# ----------
# train Loss: 0.5776, SN: 0.5794, PPV: 0.4983
# val Loss: 0.6211, SN: 0.5340, PPV: 0.4092
#
# Epoch 58/100
# ----------
# train Loss: 0.5765, SN: 0.5607, PPV: 0.4934
# val Loss: 0.6187, SN: 0.6172, PPV: 0.4544
#
# Epoch 59/100
# ----------
# train Loss: 0.5790, SN: 0.5919, PPV: 0.4995
# val Loss: 0.6391, SN: 0.5006, PPV: 0.5438
#
# Epoch 60/100
# ----------
# train Loss: 0.5711, SN: 0.5532, PPV: 0.4891
# val Loss: 0.6181, SN: 0.5912, PPV: 0.4687
#
# Epoch 61/100
# ----------
# train Loss: 0.5971, SN: 0.5829, PPV: 0.4592
# val Loss: 0.7202, SN: 0.2648, PPV: 0.5321
#
# Epoch 62/100
# ----------
# train Loss: 0.6101, SN: 0.5392, PPV: 0.4995
# val Loss: 0.6582, SN: 0.4166, PPV: 0.5493
#
# Epoch 63/100
# ----------
# train Loss: 0.5986, SN: 0.5502, PPV: 0.4713
# val Loss: 0.6628, SN: 0.4566, PPV: 0.5161
#
# Epoch 64/100
# ----------
# train Loss: 0.5967, SN: 0.5646, PPV: 0.4692
# val Loss: 0.6420, SN: 0.4642, PPV: 0.5713
#
# Epoch 65/100
# ----------
# train Loss: 0.6051, SN: 0.5567, PPV: 0.4988
# val Loss: 0.6505, SN: 0.5575, PPV: 0.2974
#
# Epoch 66/100
# ----------
# train Loss: 0.5939, SN: 0.5829, PPV: 0.4826
# val Loss: 0.6323, SN: 0.4544, PPV: 0.5086
#
# Epoch 67/100
# ----------
# train Loss: 0.5838, SN: 0.5589, PPV: 0.4996
# val Loss: 0.6256, SN: 0.6213, PPV: 0.4446
#
# Epoch 68/100
# ----------
# train Loss: 0.5887, SN: 0.5855, PPV: 0.4720
# val Loss: 0.6287, SN: 0.4668, PPV: 0.4817
#
# Epoch 69/100
# ----------
# train Loss: 0.5819, SN: 0.5815, PPV: 0.5133
# val Loss: 0.6260, SN: 0.5741, PPV: 0.5156
#
# Epoch 70/100
# ----------
# train Loss: 0.5783, SN: 0.5697, PPV: 0.4916
# val Loss: 0.6307, SN: 0.5306, PPV: 0.4787
#
# Epoch 71/100
# ----------
# train Loss: 0.5771, SN: 0.5761, PPV: 0.4971
# val Loss: 0.6237, SN: 0.5068, PPV: 0.4376
#
# Epoch 72/100
# ----------
# train Loss: 0.5724, SN: 0.5875, PPV: 0.5271
# val Loss: 0.6308, SN: 0.5953, PPV: 0.5271
#
# Epoch 73/100
# ----------
# train Loss: 0.5785, SN: 0.5771, PPV: 0.4994
# val Loss: 0.6276, SN: 0.6680, PPV: 0.4699
# Weights of model saved at ./weights/0.6679832637310028_0.46991457641124723_0.6276046454906463.pth
#
# Epoch 74/100
# ----------
# train Loss: 0.5762, SN: 0.5728, PPV: 0.4980
# val Loss: 0.6346, SN: 0.5921, PPV: 0.5338
#
# Epoch 75/100
# ----------
# train Loss: 0.5713, SN: 0.5658, PPV: 0.5051
# val Loss: 0.6245, SN: 0.5374, PPV: 0.4934
#
# Epoch 76/100
# ----------
# train Loss: 0.5850, SN: 0.5765, PPV: 0.5065
# val Loss: 0.6232, SN: 0.6032, PPV: 0.4695
#
# Epoch 77/100
# ----------
# train Loss: 0.5792, SN: 0.5862, PPV: 0.5038
# val Loss: 0.6216, SN: 0.6388, PPV: 0.4694
#
# Epoch 78/100
# ----------
# train Loss: 0.5749, SN: 0.5574, PPV: 0.4866
# val Loss: 0.6405, SN: 0.4899, PPV: 0.5368
#
# Epoch 79/100
# ----------
# train Loss: 0.5794, SN: 0.5733, PPV: 0.5074
# val Loss: 0.6252, SN: 0.6227, PPV: 0.5074
#
# Epoch 80/100
# ----------
# train Loss: 0.5724, SN: 0.5663, PPV: 0.4967
# val Loss: 0.6257, SN: 0.5686, PPV: 0.5060
#
# Epoch 81/100
# ----------
# train Loss: 0.5752, SN: 0.5674, PPV: 0.4829
# val Loss: 0.6347, SN: 0.5575, PPV: 0.5172
#
# Epoch 82/100
# ----------
# train Loss: 0.5733, SN: 0.5681, PPV: 0.5012
# val Loss: 0.6235, SN: 0.5423, PPV: 0.4184
#
# Epoch 83/100
# ----------
# train Loss: 0.5839, SN: 0.5732, PPV: 0.4673
# val Loss: 0.6256, SN: 0.5398, PPV: 0.4673
#
# Epoch 84/100
# ----------
# train Loss: 0.5712, SN: 0.5656, PPV: 0.5044
# val Loss: 0.6339, SN: 0.5367, PPV: 0.5197
#
# Epoch 85/100
# ----------
# train Loss: 0.5798, SN: 0.5851, PPV: 0.5228
# val Loss: 0.6374, SN: 0.5149, PPV: 0.5587
#
# Epoch 86/100
# ----------
# train Loss: 0.5767, SN: 0.5767, PPV: 0.4987
# val Loss: 0.6280, SN: 0.6531, PPV: 0.4914
#
# Epoch 87/100
# ----------
# train Loss: 0.5936, SN: 0.5479, PPV: 0.4750
# val Loss: 0.6672, SN: 0.4944, PPV: 0.5276
#
# Epoch 88/100
# ----------
# train Loss: 0.5878, SN: 0.5755, PPV: 0.5159
# val Loss: 0.6242, SN: 0.5534, PPV: 0.3728
#
# Epoch 89/100
# ----------
# train Loss: 0.5860, SN: 0.5778, PPV: 0.4922
# val Loss: 0.6240, SN: 0.6426, PPV: 0.4393
#
# Epoch 90/100
# ----------
# train Loss: 0.5744, SN: 0.5651, PPV: 0.4641
# val Loss: 0.6265, SN: 0.5922, PPV: 0.5156
#
# Epoch 91/100
# ----------
# train Loss: 0.5896, SN: 0.5587, PPV: 0.4986
# val Loss: 0.6272, SN: 0.6320, PPV: 0.4761
#
# Epoch 92/100
# ----------
# train Loss: 0.5794, SN: 0.5860, PPV: 0.5010
# val Loss: 0.6284, SN: 0.6188, PPV: 0.5026
#
# Epoch 93/100
# ----------
# train Loss: 0.5774, SN: 0.5725, PPV: 0.4998
# val Loss: 0.6231, SN: 0.5826, PPV: 0.4649
#
# Epoch 94/100
# ----------
# train Loss: 0.5725, SN: 0.5831, PPV: 0.4940
# val Loss: 0.6237, SN: 0.5611, PPV: 0.4690
#
# Epoch 95/100
# ----------
# train Loss: 0.5768, SN: 0.5649, PPV: 0.4990
# val Loss: 0.6260, SN: 0.5842, PPV: 0.4835
#
# Epoch 96/100
# ----------
# train Loss: 0.5692, SN: 0.5771, PPV: 0.5138
# val Loss: 0.6346, SN: 0.6499, PPV: 0.4768
#
# Epoch 97/100
# ----------
# train Loss: 0.5798, SN: 0.5710, PPV: 0.5033
# val Loss: 0.6269, SN: 0.4954, PPV: 0.3956
#
# Epoch 98/100
# ----------
# train Loss: 0.5730, SN: 0.5642, PPV: 0.4951
# val Loss: 0.6294, SN: 0.5298, PPV: 0.4172
#
# Epoch 99/100
# ----------
# train Loss: 0.5892, SN: 0.5713, PPV: 0.4911
# val Loss: 0.6475, SN: 0.5743, PPV: 0.5454
#
# Epoch 100/100
# ----------
# train Loss: 0.5801, SN: 0.5564, PPV: 0.5046
# val Loss: 0.6596, SN: 0.6313, PPV: 0.3483
#
# Training complete in 144m 25s
# Best val SN: 0.667983, Best val PPV: 0.469915, Best Loss: 0.627605
